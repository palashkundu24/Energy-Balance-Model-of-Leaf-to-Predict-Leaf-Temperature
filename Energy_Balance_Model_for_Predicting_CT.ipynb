# %% [markdown]
# # Soil_Physics_Semester_Project_codes

# %% [markdown]
# ### Simple Energy Balance Model for Predicting Canopy Temperature

# %% [markdown]
# # Import Libraries

# %%
import math
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# # Define all Constants and Importing dataset and calculate

# %%
# Constants
ML = 2  # Leaf mass per unit projected surface area (g/m^2)
Cl = 4197  # Leaf specific heat capacity (J/kg*K)
ALBEDO = 0.2
STEFB = 5.67e-8  # Stefan-Boltzmann constant (W/m^2*K^4)
EMISS = 0.75  # Long-wave emissivity of atmosphere
BOWEN = 0.5  # Bowen Ratio
DELT = 15 * 60  # Time step (s)

# Load dataset
data = pd.read_csv("Dataset_for_SP.csv")  # Load dataset
data['DateTime'] = pd.to_datetime(data['DateTime'])  # Convert 'DateTime' column to datetime format
data = data.set_index('DateTime')

# Function to calculate net radiation
def calculate_net_radiation(SRAD, TLEAF, TAIR):
    RSW = SRAD
    RSZABS = (1 - ALBEDO) * RSW
    RLWIN = EMISS * STEFB * (TAIR ** 4)
    RLWOUT = STEFB * (TLEAF ** 4)
    RNET = RSZABS - RLWOUT + RLWIN
    return RNET

# Function to calculate sensible heat flux
def calculate_sensible_heat_flux(K, TLEAF, TAIR):
    H = K * (TLEAF - TAIR)
    return H

# Function to calculate latent heat flux
def calculate_latent_heat_flux(H):
    LE = H / BOWEN
    return LE

# Function to calculate rate of change of leaf temperature
def calculate_temperature_change(RNET, H, LE):
    DTLDT = (1.0 / (ML * Cl)) * (RNET - H - LE)
    return DTLDT

# Initialize a list to store the predicted leaf temperatures for each time step
predicted_CT_values = []

# Loop over each day in the dataset
for i in range(0, len(data), 96):  # Assuming data has 96 rows per day (15-minute intervals)
    daily_data = data.iloc[i:i+96]  # Select data for one day
    TLEAF = 280  # Initial leaf temperature to test
    
    for index, row in daily_data.iterrows():
        SRAD = row['SRAD']
        TAIR = row['TAIR']

        # Calculate net radiation
        RNET = calculate_net_radiation(SRAD, TLEAF, TAIR)

        # Calculate sensible heat flux
        K = 3.0  # Example value
        H = calculate_sensible_heat_flux(K, TLEAF, TAIR)

        # Calculate latent heat flux
        LE = calculate_latent_heat_flux(H)

        # Calculate temperature change
        DTLDT = calculate_temperature_change(RNET, H, LE)

        # Update leaf temperature
        TLEAF += DELT * DTLDT
        
        # Store the predicted leaf temperature for the current time step
        predicted_CT_values.append(TLEAF)

# Extract the actual leaf temperatures (CT) from the dataset
actual_CT_values = data['CT'].values

# Compare the predicted and actual leaf temperatures
for idx, (predicted_CT, actual_CT) in enumerate(zip(predicted_CT_values, actual_CT_values)):
    print(f"Time Step {idx + 1}: Predicted CT = {predicted_CT}, Actual CT = {actual_CT}")
# Out:
# Time Step 1: Predicted CT = 296.17666079064077, Actual CT = 297.65
# Time Step 2: Predicted CT = 287.33032199940334, Actual CT = 297.55
# Time Step 3: Predicted CT = 292.3640076585549, Actual CT = 297.75
# Time Step 4: Predicted CT = 289.5594455766159, Actual CT = 297.85
# Time Step 5: Predicted CT = 291.14117726602444, Actual CT = 297.65
# Time Step 6: Predicted CT = 289.3869447541791, Actual CT = 297.45
# Time Step 7: Predicted CT = 290.3687506245959, Actual CT = 297.25
# Time Step 8: Predicted CT = 289.8215863989529, Actual CT = 297.25
# Time Step 9: Predicted CT = 290.1272519854028, Actual CT = 297.45
# Time Step 10: Predicted CT = 289.95672282322727, Actual CT = 297.45
# Time Step 11: Predicted CT = 290.05193078937083, Actual CT = 297.35
# Time Step 12: Predicted CT = 289.27668441370616, Actual CT = 297.35
# Time Step 63: Predicted CT = 325.0485931804924, Actual CT = 305.45
# Time Step 64: Predicted CT = 295.1724914561203, Actual CT = 305.95
# Time Step 65: Predicted CT = 361.1169353233543, Actual CT = 307.15
# Time Step 66: Predicted CT = 297.5293419561973, Actual CT = 306.95
# Time Step 67: Predicted CT = 347.6134555640579, Actual CT = 305.35
# Time Step 68: Predicted CT = 303.0105513750467, Actual CT = 304.65
# Time Step 69: Predicted CT = 336.688861314637, Actual CT = 303.85
# Time Step 70: Predicted CT = 296.6558772993533, Actual CT = 306.35
# Time Step 71: Predicted CT = 321.7087536159593, Actual CT = 305.95
# Time Step 72: Predicted CT = 307.06582585251914, Actual CT = 306.05
# Time Step 73: Predicted CT = 312.991773056547, Actual CT = 306.15
# Time Step 74: Predicted CT = 304.4444260276452, Actual CT = 306.05
# Time Step 75: Predicted CT = 305.9729808139198, Actual CT = 305.45
# Time Step 76: Predicted CT = 301.36714942909833, Actual CT = 304.95
# Time Step 77: Predicted CT = 299.41950221631595, Actual CT = 304.45
# Time Step 78: Predicted CT = 296.97725895395837, Actual CT = 304.35
# Time Step 79: Predicted CT = 296.2918082557279, Actual CT = 304.05
# Time Step 80: Predicted CT = 295.53531048664615, Actual CT = 303.65
# Time Step 81: Predicted CT = 295.0149582548133, Actual CT = 303.15
# Time Step 82: Predicted CT = 294.43954875414244, Actual CT = 302.65
# Time Step 83: Predicted CT = 294.0432117674551, Actual CT = 302.05
# Time Step 84: Predicted CT = 295.0092607817073, Actual CT = 301.55
# Time Step 85: Predicted CT = 292.8288569919436, Actual CT = 301.05
# Time Step 86: Predicted CT = 293.36712366818347, Actual CT = 300.45
# Time Step 87: Predicted CT = 292.18003648894177, Actual CT = 300.15
# Time Step 88: Predicted CT = 292.8628891019672, Actual CT = 299.15
# Time Step 89: Predicted CT = 292.47116599302086, Actual CT = 299.75
# Time Step 90: Predicted CT = 291.0941754743072, Actual CT = 298.75
# Time Step 91: Predicted CT = 291.15151752132056, Actual CT = 298.05
# Time Step 92: Predicted CT = 291.1191211575805, Actual CT = 297.95
# Time Step 93: Predicted CT = 290.26754115706274, Actual CT = 298.15
# Time Step 94: Predicted CT = 290.74639867915835, Actual CT = 298.05
# Time Step 95: Predicted CT = 290.47767937560985, Actual CT = 297.35
# Time Step 96: Predicted CT = 290.6286497478181, Actual CT = 296.95

# %%
# Open a CSV file named "leaf_temperatures.csv" in write mode
with open("leaf_temperatures.csv", "w", newline='') as csvfile:
    # Create a CSV writer object
    writer = csv.writer(csvfile)
    
    # Write header
    writer.writerow(["DateTime", "Actual_CT", "Predicted_CT"])
    
    # Write data
    for idx, (actual_CT, predicted_CT) in enumerate(zip(actual_CT_values, predicted_CT_values)):
        date_time = data.index[idx]
        writer.writerow([date_time, actual_CT, predicted_CT])

print("Data saved to leaf_temperatures.csv")
# Out:
# Data saved to leaf_temperatures.csv

# %% [markdown]
# # Plot actual vs predicted CT with datetime on x-axis

# %%
plt.figure(figsize=(10, 6))
plt.plot(data.index, actual_CT_values, label='Actual CT', color='blue')
plt.plot(data.index, predicted_CT_values, label='Predicted CT', linestyle='--', color='red')
plt.xlabel('Date and Time', weight='bold', fontsize='16')
plt.ylabel('Leaf Temperature (K)', weight='bold', fontsize='16')
plt.title('Actual vs Predicted Leaf Temperature (CT)', weight='bold', fontsize='16')
plt.legend(fontsize='14')
plt.grid(False)
plt.xticks(rotation=0,fontsize='14') 
plt.yticks(fontsize='14')
plt.tight_layout()
plt.show()
